# %%
# !pip install quandl yfinance
import pandas as pd
import quandl
import yfinance as yf
import numpy as np
import requests
import matplotlib.pyplot as plt



# Function for the api request to get the data from td ameritrade
def us_hist_request(stock):
    """
    Makes an api call for a list of stock symbols
    and returns a dataframe
    """
    td_api_key = r"PZBFTNFXZAI6GCTYUGDBUDBDFSUKJXQK"
    url = r"https://api.tdameritrade.com/v1/marketdata/{}/pricehistory".format(stock)

    params = {
        'apikey': td_api_key,
        'periodType': 'year',
        'period': '5',
        'frequencyType': 'daily',
        'frequency': '1',
        'needExtendedHoursData': 'true'
    }

    request = requests.get(
        url=url,
        params=params
    ).json()


    try:
        df = pd.DataFrame(request['candles'])


        df.set_index('datetime', inplace=True)
        df.index = pd.to_datetime(df.index, unit='ms').date
        return df
    except:
        print("ERROR in TD AMERITRADE API CALL")
        print(request)


def hk_hist_request(stock):
    quandl.ApiConfig.api_key = r"j2QGEgPyPhe-dGsNNtzE"
    return quandl.get(f"HKEX/{stock}")

def fx_hist_request(fx_sym):
    fx = yf.Ticker(fx_sym)
    return fx.history(period="max")

us_li = ['ARKK', 'CGW', 'TSM']
hk_li = ['02823', '02834']
fx_li = ["USDHKD=X", "HKDGBP=X"]


execution_date = "2021-04-08"

df_us = pd.concat([us_hist_request(us_sym)['close'].rename(us_sym) for us_sym in us_li], axis=1)
df_hk = pd.concat([hk_hist_request(hk_sym)['Nominal Price'].rename(hk_sym) for hk_sym in hk_li], axis=1)
df_fx = pd.concat([fx_hist_request(fx_sym)['Close'].rename(fx_sym.split('=')[0]) for fx_sym in fx_li], axis=1)[execution_date:]

hist_df = df_us.sort_index().merge(df_hk, how='left', left_index=True, right_index=True)[['02823', '02834','ARKK', 'CGW', 'TSM']]

## Execution prices and volumes

executed = pd.DataFrame([[19.65, 258, 122.51, 50.23, 121.57],
              [3300, 300, 48, 202, 60]], 
              columns=['02823', '02834','ARKK', 'CGW', 'TSM'], index=['price', 'volume'])



execution_date_plus_one = "2021-04-09"
port_hist_df = hist_df[execution_date_plus_one:]

## need to correct close price on execution date with execution price
port_hist_df.loc[pd.to_datetime('2021-04-08')] = executed.loc['price'].values.tolist()


port_val = executed.loc['volume'] * port_hist_df.sort_index()
for us_sym in us_li:
  port_val[us_sym] = port_val[us_sym]* df_fx['USDHKD']

port_val['hkd_val'] = port_val.sum(axis=1)
port_val['gbp_val'] = port_val['hkd_val']*df_fx['HKDGBP']

port_val['gbp_ret'] = port_val['gbp_val'].pct_change(1)
port_val['gbp_cumret'] = (port_val['gbp_ret'].fillna(0)+1).cumprod()

## Individual stock cumulative returns
stocks_cumret = (port_hist_df.sort_index().pct_change().fillna(0) +1)


## Portfolio Statistics

window = 126
def dd(ts):
  return np.min(ts/np.maximum.accumulate(ts)) -1 

port_val['max_dd'] = port_val['gbp_val'].rolling(window, min_periods=1).apply(dd)


port_stats = pd.Series({'annu Sharpe': np.sqrt(252) *port_val['gbp_ret'].mean() / port_val['gbp_ret'].std(),
                        'curr PnL (GBP)': port_val['gbp_val'][-1] - port_val['gbp_val'][0],
                        'curr PnL (cum ret)': port_val['gbp_cumret'][-1] - 1,
                        'Max DD': np.min(port_val['max_dd']),
                        'daily avg ret': port_val['gbp_ret'].mean(),
                        'daily avg ret (GBP)': port_val['gbp_ret'].mean()* port_val['gbp_val'][-1],
                        'daily vol': port_val['gbp_ret'].std(),
                        'daily vol (GBP)': port_val['gbp_ret'].std()* port_val['gbp_val'][-1],
                        'daily_skew': port_val['gbp_ret'].skew()
                        })
# Out:
# Requirement already satisfied: quandl in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (3.6.1)
# Requirement already satisfied: yfinance in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (0.1.54)
# Requirement already satisfied: six in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (1.14.0)
# Requirement already satisfied: numpy>=1.8 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (1.18.1)
# Requirement already satisfied: requests>=2.7.0 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (2.22.0)
# Requirement already satisfied: python-dateutil in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (2.8.1)
# Requirement already satisfied: pandas>=0.14 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (1.1.1)
# Requirement already satisfied: more-itertools in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (7.2.0)
# Requirement already satisfied: inflection>=0.3.1 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from quandl) (0.5.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (2.8)
# Requirement already satisfied: pytz>=2017.2 in /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages (from pandas>=0.14->quandl) (2020.1)
# /Users/kingf.wong/anaconda3/envs/FinanceML2/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
print('Portfolio Stats')
port_stats
# Out:
# Portfolio Stats
# annu Sharpe              1.068291
# curr PnL (GBP)         186.120320
# curr PnL (cum ret)       0.006148
# Max DD                  -0.025663
# daily avg ret            0.000593
# daily avg ret (GBP)     18.050569
# daily vol                0.008806
# daily vol (GBP)        268.226541
# daily_skew              -0.159540
# dtype: float64

# %%
print('Assets Cumulative Returns')
((hist_df['2021-04-08':].pct_change().fillna(0)+1).cumprod() -1).iloc[-1].sort_values(ascending=False).rename(None, axis=1)
# Out:
# Assets Cumulative Returns
# CGW      0.046151
# 02823    0.013747
# 02834    0.004653
# ARKK    -0.003544
# TSM     -0.038807
# dtype: float64

# %%
print('Current Portfolio Weight')
port_val[['02823', '02834','ARKK', 'CGW', 'TSM']].div(port_val['hkd_val'], axis=0).iloc[-1].rename(None, axis=1).sort_values(ascending=False)
# Out:
# Current Portfolio Weight
# CGW      0.251953
# 02834    0.237577
# 02823    0.200817
# TSM      0.168829
# ARKK     0.140824
# dtype: float64

# %%
gbp_ax = port_val['gbp_val'].plot(figsize=(20,10))
gbp_ax.set_ylabel("Portfolio Val (GBP)", fontsize=20)
plt.show()

# %%
hkd_ax = port_val['hkd_val'].plot(figsize=(15,10))
hkd_ax.set_ylabel("Portfolio Val (HKD)", fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
## Portfolio Weight
port_weights = port_val[['02823', '02834','ARKK', 'CGW', 'TSM']].div(port_val['hkd_val'], axis=0).plot(figsize=(15,10))
port_weights.set_ylabel('Portfolio Weights', fontsize=20)
port_weights.legend(loc=2)
_=plt.yticks(fontsize=20)

# %%
hist_cumret = (hist_df['2021-04-08':].pct_change().fillna(0)+1).cumprod()
etfs_ret_ax = hist_cumret.plot(figsize=(15,10))
etfs_ret_ax.set_ylabel('Cum Returns', fontsize=20)
_= plt.yticks(fontsize=20)

# %%
## Cumulative Forex Returns 
print(f"Current HKDGBP Returns (GBP/ HKD): {round(df_fx.HKDGBP.iloc[-1]/df_fx.HKDGBP.iloc[0]-1, 5)}")

fx_ret = ((df_fx.HKDGBP.pct_change(1).fillna(0)+1).cumprod() -1).plot(figsize=(15,10))
fx_ret.set_ylabel('HKDGBP Returns (GBP/ HKD)', fontsize=20)

fx_price = fx_ret.twinx()
df_fx.HKDGBP.plot(ax=fx_price)
fx_price.set_ylabel('HKDGBP', fontsize=20)


_ =plt.yticks(fontsize=15)
# Out:
# Current HKDGBP Returns (GBP/ HKD): -0.00428
